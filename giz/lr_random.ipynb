# %%
import numpy as np

# %%
X= 2* np.random.rand(100,1)

# %%
X.shape
# Out:
# (100, 1)

# %%
y = 4 + 3 * X + np.random.randn(100, 1)

# %%
y
# Out:
# array([[ 9.30580416],
#        [ 5.78068611],
#        [ 6.84020856],
#        [ 9.89208257],
#        [ 4.78003697],
#        [ 4.17842852],
#        [ 3.10024043],
#        [ 2.95246841],
#        [ 4.27593979],
#        [ 4.90214909],
#        [10.97828095],
#        [ 4.49274352],
#        [ 7.33352706],
#        [ 8.18232275],
#        [ 7.65904714],
#        [ 3.52918554],
#        [ 8.0359212 ],
#        [ 5.75144939],
#        [ 6.02447956],
#        [ 4.56190773],
#        [ 5.27970284],
#        [ 8.01749258],
#        [ 5.17700543],
#        [11.35078071],
#        [ 9.49161497],
#        [ 9.1711447 ],
#        [ 8.27533274],
#        [ 5.35392692],
#        [ 9.68076482],
#        [ 9.34670559],
#        [ 4.57693021],
#        [ 7.25346066],
#        [ 9.45978411],
#        [ 8.5048165 ],
#        [ 6.79397841],
#        [ 7.39773247],
#        [ 6.88599314],
#        [ 7.72510357],
#        [ 4.1414215 ],
#        [ 8.86833125],
#        [ 9.04590663],
#        [ 8.77482908],
#        [ 6.00963253],
#        [ 4.05962365],
#        [ 8.84019758],
#        [ 6.03674439],
#        [ 8.96425724],
#        [ 3.65007744],
#        [ 7.93005036],
#        [ 5.15044773],
#        [ 9.2699017 ],
#        [ 5.94143439],
#        [ 4.55389372],
#        [ 6.45516433],
#        [ 7.26774049],
#        [ 9.16303774],
#        [ 6.7144905 ],
#        [ 7.18766329],
#        [ 7.05439111],
#        [ 8.66484398],
#        [ 6.7391821 ],
#        [ 3.42179623],
#        [ 5.60387582],
#        [ 7.12616645],
#        [ 8.45687059],
#        [ 5.77411846],
#        [ 5.41991451],
#        [ 4.67421419],
#        [ 7.41280462],
#        [ 4.86113086],
#        [ 9.33186324],
#        [ 6.00413601],
#        [ 4.3550379 ],
#        [ 8.67990836],
#        [ 5.25642883],
#        [ 2.91041077],
#        [ 5.94333079],
#        [ 7.01103226],
#        [ 6.68672333],
#        [ 6.85572534],
#        [ 7.74585712],
#        [ 8.53133709],
#        [ 5.32301515],
#        [ 8.91364172],
#        [ 9.93525283],
#        [ 8.20992812],
#        [ 7.82327205],
#        [ 3.54253377],
#        [ 9.06162561],
#        [ 6.9389387 ],
#        [ 8.89071237],
#        [ 8.14695267],
#        [ 6.6236491 ],
#        [ 6.09506392],
#        [ 6.20870838],
#        [ 8.52075066],
#        [ 5.90693028],
#        [ 7.13011748],
#        [ 9.99583914],
#        [ 4.95528207]])

# %%
X_b = np.c_[np.ones((100, 1)), X]  
# add x0 = 1 to each instancetheta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)

# %%
X_b = np.c_[np.ones((100,1)), X]

# %%
X_b
# Out:
# array([[1.        , 1.46042228],
#        [1.        , 0.39468688],
#        [1.        , 0.7510819 ],
#        [1.        , 1.46450433],
#        [1.        , 0.2958933 ],
#        [1.        , 0.00839678],
#        [1.        , 0.37770186],
#        [1.        , 0.18363633],
#        [1.        , 0.55258758],
#        [1.        , 0.00597038],
#        [1.        , 1.66951939],
#        [1.        , 0.19489404],
#        [1.        , 1.17949625],
#        [1.        , 0.85605229],
#        [1.        , 0.2798562 ],
#        [1.        , 0.07452553],
#        [1.        , 1.43970651],
#        [1.        , 0.60059964],
#        [1.        , 0.79588787],
#        [1.        , 0.26844679],
#        [1.        , 0.73223993],
#        [1.        , 1.36103573],
#        [1.        , 0.06322818],
#        [1.        , 1.93000969],
#        [1.        , 1.55131179],
#        [1.        , 1.72973219],
#        [1.        , 1.08547047],
#        [1.        , 0.38937708],
#        [1.        , 1.73563928],
#        [1.        , 1.84703381],
#        [1.        , 0.3268868 ],
#        [1.        , 0.91059198],
#        [1.        , 1.17454552],
#        [1.        , 1.98340402],
#        [1.        , 1.23460837],
#        [1.        , 1.06821199],
#        [1.        , 0.83081623],
#        [1.        , 0.95917886],
#        [1.        , 0.35823794],
#        [1.        , 1.69159348],
#        [1.        , 1.83921027],
#        [1.        , 1.65010379],
#        [1.        , 0.73258288],
#        [1.        , 0.17289458],
#        [1.        , 1.06646332],
#        [1.        , 0.82802536],
#        [1.        , 1.70227475],
#        [1.        , 0.41530122],
#        [1.        , 1.44066082],
#        [1.        , 0.38191442],
#        [1.        , 1.76734605],
#        [1.        , 0.22419008],
#        [1.        , 0.63579592],
#        [1.        , 0.14378945],
#        [1.        , 1.29987498],
#        [1.        , 1.65603503],
#        [1.        , 0.98747714],
#        [1.        , 1.8311769 ],
#        [1.        , 0.56216385],
#        [1.        , 1.25150886],
#        [1.        , 0.89566529],
#        [1.        , 0.00607911],
#        [1.        , 0.37254578],
#        [1.        , 1.19393751],
#        [1.        , 1.40312117],
#        [1.        , 1.10001141],
#        [1.        , 0.82660024],
#        [1.        , 0.11530018],
#        [1.        , 1.24407742],
#        [1.        , 0.31288003],
#        [1.        , 1.67264999],
#        [1.        , 0.78385929],
#        [1.        , 0.05260818],
#        [1.        , 1.22441952],
#        [1.        , 0.78221654],
#        [1.        , 0.41855051],
#        [1.        , 1.00014234],
#        [1.        , 0.46105131],
#        [1.        , 0.64216985],
#        [1.        , 1.18314406],
#        [1.        , 1.36083832],
#        [1.        , 1.51328668],
#        [1.        , 0.69702054],
#        [1.        , 1.91607917],
#        [1.        , 1.51910102],
#        [1.        , 1.17159411],
#        [1.        , 1.47480104],
#        [1.        , 0.00786727],
#        [1.        , 1.97210511],
#        [1.        , 1.33877948],
#        [1.        , 1.18408338],
#        [1.        , 1.72501573],
#        [1.        , 0.69365746],
#        [1.        , 1.15526053],
#        [1.        , 0.91746975],
#        [1.        , 1.39871587],
#        [1.        , 0.41837215],
#        [1.        , 1.13512358],
#        [1.        , 1.34483765],
#        [1.        , 0.08970548]])

# %%
theta = np.random.randint(low=5, high= 100)

# %%
theta
# Out:
# 10

# %%
ite = 10
for i in range(5):
    theta = np.random.randn(2,10)
    print(theta)
# Out:
# [[ 1.09393982 -0.56139816 -0.27642852 -1.45602467 -0.12577045  0.17008219
#    0.53991112 -1.29237831 -0.64063196 -1.01632032]
#  [-0.16772506  0.25010038 -0.05894936 -0.05982926  0.61793452  1.24428501
#    0.06807996 -1.06547    -1.51704618  1.08597001]]
# [[ 0.82697599  1.23564859  0.83126577  1.57930494  0.59013703  0.73814881
#    0.55113834  0.54996037 -2.54381682 -0.97363135]
#  [ 0.34590739  0.70535307 -0.25079015 -0.5852409   0.27625922  2.17408289
#    0.10268581  2.28609419  0.4216248  -0.12535514]]
# [[ 0.30892113  0.05597309  0.20623213 -0.33671626  0.35356396  1.42710732
#   -0.65889866 -1.58329279  0.53638692  2.58781266]
#  [ 0.28602561 -1.44004858 -0.44914499  1.12039657 -0.7197397  -0.99673187
#   -0.36028357  0.07556594 -0.03790039  1.66169041]]
# [[ 0.62999166  0.34026602  0.23327334 -0.35780775 -1.20529819 -2.02366377
#   -1.94681842 -0.6116192   1.08071104 -0.40960229]
#  [ 0.12511835 -0.01018309  0.70899159  0.07701451  0.16220977  1.16982206
#    0.6578899  -0.61237056 -0.0641436   0.61410576]]
# [[-1.19095566  1.30954512  0.9273522  -1.17271041 -0.00350336 -0.18243022
#   -0.78530018 -0.0505703  -0.6052255   0.01706465]
#  [-0.18856609 -0.55758527 -0.7066752   0.26126179  0.25688561 -2.14979749
#   -0.30815782 -0.40600629  0.39416017 -0.46975823]]

# %%
import numpy as np

# %%
from sklearn.datasets import load_iris
from sklearn.linear_model import Perceptron

# %%
iris = load_iris()

# %%
X.shape
# Out:
# (150, 2)

# %%
y = (iris.target == 0).astype(np.int)

# %%
per_clf = Perceptron()

# %%
per_clf
# Out:
# Perceptron()

# %%
per_clf.fit(X,y)
# Out:
# Perceptron()

# %%
y_pred = per_clf.predict([[2, 0.5]])
print(y_pred)
# Out:
# [0]
