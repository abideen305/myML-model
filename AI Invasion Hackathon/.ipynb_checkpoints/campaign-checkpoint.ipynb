# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pydot
# %matplotlib inline 
#this is for Back End of the matplotlib for better visualization

# %%
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")
sub_samp = pd.read_csv("sample_submission.csv")

# %%
df_train.head()
# Out:
#          customer_id  age          job  marital          education  default  \
# 0  customer_id_39075   31       admin.  married  university.degree       no
# 1  customer_id_34855   31   technician   single  university.degree       no
# 2   customer_id_7107   47  blue-collar  married           basic.6y  unknown
# 3  customer_id_31614   36     services  married  university.degree       no
# 4  customer_id_34878   34       admin.   single        high.school       no
#
#   housing loan    contact month  ... campaign  pdays  previous     poutcome  \
# 0      no   no   cellular   dec  ...        3    999         1      failure
# 1      no   no  telephone   may  ...        4    999         0  nonexistent
# 2     yes   no  telephone   may  ...        2    999         0  nonexistent
# 3      no   no   cellular   may  ...        1    999         1      failure
# 4      no   no   cellular   may  ...        9    999         0  nonexistent
#
# ...

# %%
df_test.head()
# Out:
#          customer_id  age          job  marital    education  default housing  \
# 0  customer_id_32884   59   technician  married  high.school       no      no
# 1   customer_id_3169   57      unknown  married      unknown  unknown     yes
# 2  customer_id_32206   35  blue-collar  married     basic.9y       no      no
# 3   customer_id_9403   38       admin.  married  high.school       no      no
# 4  customer_id_14020   29    housemaid  married  high.school       no     yes
#
#   loan    contact month  ...  duration  campaign  pdays  previous  \
# 0  yes   cellular   may  ...  6.183333         1    999         1
# 1   no  telephone   may  ...  4.750000         2    999         0
# 2   no   cellular   may  ...  0.866667         1    999         1
# 3   no  telephone   jun  ...  5.916667         4    999         0
# 4   no   cellular   jul  ...  3.150000         2    999         0
#
#       poutcome emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  \
# ...

# %%
sub_samp.head()
# Out:
#          customer_id  subscribed
# 0  customer_id_32884           1
# 1   customer_id_3169           1
# 2  customer_id_32206           1
# 3   customer_id_9403           1
# 4  customer_id_14020           1

# %%
#printing their shapes

print("The shape for train is {}.\n The shape for test is {}.".format(df_train.shape, df_test.shape))
# Out:
# The shape for train is (28831, 22).
#  The shape for test is (12357, 21).

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28831 entries, 0 to 28830
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     28831 non-null  object
#  1   age             28831 non-null  int64
#  2   job             28831 non-null  object
#  3   marital         28831 non-null  object
#  4   education       28831 non-null  object
#  5   default         28831 non-null  object
#  6   housing         28831 non-null  object
#  7   loan            28831 non-null  object
#  8   contact         28831 non-null  object
#  9   month           28831 non-null  object
#  10  day_of_week     28831 non-null  object
#  11  duration        28831 non-null  float64
#  12  campaign        28831 non-null  int64
#  13  pdays           28831 non-null  int64
#  14  previous        28831 non-null  int64
#  15  poutcome        28831 non-null  object
#  16  emp_var_rate    28831 non-null  float64
# ...

# %%
df_train.columns
# Out:
# Index(['customer_id', 'age', 'job', 'marital', 'education', 'default',
#        'housing', 'loan', 'contact', 'month', 'day_of_week', 'duration',
#        'campaign', 'pdays', 'previous', 'poutcome', 'emp_var_rate',
#        'cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed',
#        'subscribed'],
#       dtype='object')

# %%
df_train = df_train.drop(columns=["cons_conf_idx", "nr_employed", "customer_id", "pdays", "month", "previous"], axis = 1)
df_test = df_test.drop(columns=["cons_conf_idx", "nr_employed", "customer_id", "pdays", "month", "previous"], axis = 1)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28831 entries, 0 to 28830
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             28831 non-null  int64
#  1   job             28831 non-null  object
#  2   marital         28831 non-null  object
#  3   education       28831 non-null  object
#  4   default         28831 non-null  object
#  5   housing         28831 non-null  object
#  6   loan            28831 non-null  object
#  7   contact         28831 non-null  object
#  8   day_of_week     28831 non-null  object
#  9   duration        28831 non-null  float64
#  10  campaign        28831 non-null  int64
#  11  poutcome        28831 non-null  object
#  12  emp_var_rate    28831 non-null  float64
#  13  cons_price_idx  28831 non-null  float64
#  14  euribor3m       28831 non-null  float64
#  15  subscribed      28831 non-null  int64
# dtypes: float64(4), int64(3), object(9)
# ...

# %%
df_train= pd.get_dummies(df_train)
df_test= pd.get_dummies(df_test)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28831 entries, 0 to 28830
# Data columns (total 50 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   age                            28831 non-null  int64
#  1   duration                       28831 non-null  float64
#  2   campaign                       28831 non-null  int64
#  3   emp_var_rate                   28831 non-null  float64
#  4   cons_price_idx                 28831 non-null  float64
#  5   euribor3m                      28831 non-null  float64
#  6   subscribed                     28831 non-null  int64
#  7   job_admin.                     28831 non-null  uint8
#  8   job_blue-collar                28831 non-null  uint8
#  9   job_entrepreneur               28831 non-null  uint8
#  10  job_housemaid                  28831 non-null  uint8
#  11  job_management                 28831 non-null  uint8
# ...

# %%
df_train.isnull().sum()
# Out:
# age                              0
# duration                         0
# campaign                         0
# emp_var_rate                     0
# cons_price_idx                   0
# euribor3m                        0
# subscribed                       0
# job_admin.                       0
# job_blue-collar                  0
# job_entrepreneur                 0
# job_housemaid                    0
# job_management                   0
# job_retired                      0
# job_self-employed                0
# job_services                     0
# job_student                      0
# job_technician                   0
# job_unemployed                   0
# job_unknown                      0
# marital_divorced                 0
# marital_married                  0
# marital_single                   0
# marital_unknown                  0
# education_basic.4y               0
# education_basic.6y               0
# education_basic.9y               0
# education_high.school            0
# ...

# %%
X=df_train.drop(['subscribed'],axis=1)

# %%
X.head()
# Out:
#    age   duration  campaign  emp_var_rate  cons_price_idx  euribor3m  \
# 0   31   1.283333         3         -2.97         46.3565      1.711
# 1   31   0.200000         4         -1.77         46.4465      2.252
# 2   47   4.616667         2          1.13         46.9970      5.862
# 3   36   1.166667         1         -1.77         46.4465      2.329
# 4   34  19.683333         9         -1.77         46.4465      2.252
#
#    job_admin.  job_blue-collar  job_entrepreneur  job_housemaid  ...  \
# 0           1                0                 0              0  ...
# 1           0                0                 0              0  ...
# 2           0                1                 0              0  ...
# 3           0                0                 0              0  ...
# 4           1                0                 0              0  ...
#
#    contact_cellular  contact_telephone  day_of_week_fri  day_of_week_mon  \
# ...

# %%
y = df['subscribed']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2,  stratify = y,random_state = 42)

# %%
#Let's start by using Logistic Regression model since the problem is about classification
from sklearn.linear_model import LogisticRegression
#instanciating the model
lr = LogisticRegression(max_iter=100000)

# %%
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=100000)

# %%
lr_pr = lr.predict(df_test)

# %%
lr_pr
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
lr_pr.shape
# Out:
# (12357,)

# %%
from sklearn.metrics import f1_score

# %%
acc = f1_score(y_test, lr_pred)

# %%
acc
# Out:
# 0.5289099526066351

# %%
lr_submission = pd.DataFrame({"customer_id": test_id, "subscribed": lr_pr})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-06389c678534> in <module>
# ----> 1 svm_submission = pd.DataFrame({"customer_id": test_id2, "subscribed": lr_pred})
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ...

# %%
lr_submission_csv = svm_submission.to_csv("lr_Submission.csv", index=False)
