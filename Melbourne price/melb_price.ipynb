# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pydot
# %matplotlib inline 
#this is for Back End of the matplotlib for better visualization

# %%
melb = pd.read_csv("melb_data.csv")

# %%
melb.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
melb.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
melb = melb.dropna(axis=0)

# %%
melb.describe()
# Out:
#              Rooms         Price     Distance     Postcode     Bedroom2  \
# count  6196.000000  6.196000e+03  6196.000000  6196.000000  6196.000000
# mean      2.931407  1.068828e+06     9.751097  3101.947708     2.902034
# std       0.971079  6.751564e+05     5.612065    86.421604     0.970055
# min       1.000000  1.310000e+05     0.000000  3000.000000     0.000000
# 25%       2.000000  6.200000e+05     5.900000  3044.000000     2.000000
# 50%       3.000000  8.800000e+05     9.000000  3081.000000     3.000000
# 75%       4.000000  1.325000e+06    12.400000  3147.000000     3.000000
# max       8.000000  9.000000e+06    47.400000  3977.000000     9.000000
#
#           Bathroom          Car      Landsize  BuildingArea    YearBuilt  \
# count  6196.000000  6196.000000   6196.000000   6196.000000  6196.000000
# mean      1.576340     1.573596    471.006940    141.568645  1964.081988
# std       0.711362     0.929947    897.449881     90.834824    38.105673
# ...

# %%
y = melb.Price

# %%
melb_f = ['Rooms', 'Bathroom', 'Landsize', 'Lattitude', 'Longtitude']

# %%
X = melb[melb_f]

# %%
X
# Out:
#        Rooms  Bathroom  Landsize  Lattitude  Longtitude
# 1          2       1.0     156.0  -37.80790   144.99340
# 2          3       2.0     134.0  -37.80930   144.99440
# 4          4       1.0     120.0  -37.80720   144.99410
# 6          3       2.0     245.0  -37.80240   144.99930
# 7          2       1.0     256.0  -37.80600   144.99540
# ...      ...       ...       ...        ...         ...
# 12205      3       2.0     972.0  -37.51232   145.13282
# 12206      3       1.0     179.0  -37.86558   144.90474
# 12207      1       1.0       0.0  -37.85588   144.89936
# 12209      2       1.0       0.0  -37.85581   144.99025
# 12212      6       3.0    1087.0  -37.81038   144.89389
#
# [6196 rows x 5 columns]

# %%
X.describe()
# Out:
#              Rooms     Bathroom      Landsize    Lattitude   Longtitude
# count  6196.000000  6196.000000   6196.000000  6196.000000  6196.000000
# mean      2.931407     1.576340    471.006940   -37.807904   144.990201
# std       0.971079     0.711362    897.449881     0.075850     0.099165
# min       1.000000     1.000000      0.000000   -38.164920   144.542370
# 25%       2.000000     1.000000    152.000000   -37.855438   144.926198
# 50%       3.000000     1.000000    373.000000   -37.802250   144.995800
# 75%       4.000000     2.000000    628.000000   -37.758200   145.052700
# max       8.000000     8.000000  37000.000000   -37.457090   145.526350

# %%
X.corr()
# Out:
#                Rooms  Bathroom  Landsize  Lattitude  Longtitude
# Rooms       1.000000  0.613853  0.098755   0.016049    0.088031
# Bathroom    0.613853  1.000000  0.076295  -0.072020    0.116103
# Landsize    0.098755  0.076295  1.000000   0.005610    0.032918
# Lattitude   0.016049 -0.072020  0.005610   1.000000   -0.357988
# Longtitude  0.088031  0.116103  0.032918  -0.357988    1.000000

# %%
sns.heatmap(X.corr())
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
melb_model = DecisionTreeRegressor(random_state=1)

# %%
melb_model.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
melb_pred =melb_model.predict(X)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
melb_acc = mean_absolute_error(y, melb_pred )

# %%
melb_acc
# Out:
# 1115.7467183128902

# %%
def get_mae(max_leaf_nodes, X, y):
    model = DecisionTreeRegressor(max_leaf_nodes= max_leaf_nodes, random_state=42)
    model = melb_model.fit(X,y)
    pred = model.predict(X)
    mae = mean_absolute_error(y, pred)
    print(mae)

# %%
get_mae(156,X, y)
# Out:
# 1115.7467183128902

# %%
candidate_max_leaf_nodes = [5, 25, 50, 100, 250, 500]
# Write loop to find the ideal tree size from candidate_max_leaf_nodes
for max_leaf_nodes in candidate_max_leaf_nodes:
    best_tree_size = get_mae(max_leaf_nodes, X,y)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, best_tree_size))
# Out:
# Max leaf nodes: 5  		 Mean Absolute Error:  355260
# Max leaf nodes: 25  		 Mean Absolute Error:  270781
# Max leaf nodes: 50  		 Mean Absolute Error:  236552
# Max leaf nodes: 100  		 Mean Absolute Error:  209584
# Max leaf nodes: 250  		 Mean Absolute Error:  165655
# Max leaf nodes: 500  		 Mean Absolute Error:  126642

# %%
get_mae(11,X, y)
# Out:
# 308296.9723933471
